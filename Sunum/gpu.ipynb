# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt
sndr=pd.read_csv('GPU_sender_values.csv')
both=pd.read_csv('GPU_seboth_values.csv')
sndr
# Out:
#                   timestamp                          name         pci.bus_id  \
# 0   2022/12/21 13:58:01.105   NVIDIA GeForce GTX 1060 6GB   00000000:01:00.0
# 1   2022/12/21 13:58:04.106   NVIDIA GeForce GTX 1060 6GB   00000000:01:00.0
# 2   2022/12/21 13:58:07.106   NVIDIA GeForce GTX 1060 6GB   00000000:01:00.0
# 3   2022/12/21 13:58:10.107   NVIDIA GeForce GTX 1060 6GB   00000000:01:00.0
# 4   2022/12/21 13:58:13.108   NVIDIA GeForce GTX 1060 6GB   00000000:01:00.0
# 5   2022/12/21 13:58:16.109   NVIDIA GeForce GTX 1060 6GB   00000000:01:00.0
# 6   2022/12/21 13:58:19.109   NVIDIA GeForce GTX 1060 6GB   00000000:01:00.0
# 7   2022/12/21 13:58:22.110   NVIDIA GeForce GTX 1060 6GB   00000000:01:00.0
# 8   2022/12/21 13:58:25.111   NVIDIA GeForce GTX 1060 6GB   00000000:01:00.0
# 9   2022/12/21 13:58:28.111   NVIDIA GeForce GTX 1060 6GB   00000000:01:00.0
# 10  2022/12/21 13:58:31.112   NVIDIA GeForce GTX 1060 6GB   00000000:01:00.0
# ...

# %%
for i in range(len(sndr)):
    sndr[' memory.used [MiB]'].iloc[i]=int(sndr[' memory.used [MiB]'].iloc[i].split(' ')[1])
for i in range(len(both)):
    both[' memory.used [MiB]'].iloc[i]=int(both[' memory.used [MiB]'].iloc[i].split(' ')[1])
# Out:
# /tmp/ipykernel_52140/3879493830.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sndr[' memory.used [MiB]'].iloc[i]=int(sndr[' memory.used [MiB]'].iloc[i].split(' ')[1])
# /tmp/ipykernel_52140/3879493830.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   both[' memory.used [MiB]'].iloc[i]=int(both[' memory.used [MiB]'].iloc[i].split(' ')[1])

# %%
sndr[' memory.used [MiB]'].plot()
# Out:
# <AxesSubplot: >

# %%
both[' memory.used [MiB]'].plot()
# Out:
# <AxesSubplot: >
