# %%
import sys
import gi
import logging

gi.require_version("GLib", "2.0")
gi.require_version("GObject", "2.0")
gi.require_version("Gst", "1.0")

from gi.repository import Gst, GLib, GObject

uri_name='rtsp://127.0.0.1:8554/test'
file='ElephantsDream.mp4'

def cb_newpad(decodebin, decoder_src_pad,data):
    print("In cb_newpad\n")
    caps=decoder_src_pad.get_current_caps()
    gststruct=caps.get_structure(0)
    gstname=gststruct.get_name()
    source_bin=data
    features=caps.get_features(0)

    print("gstname=",gstname)
    if(gstname.find("video")!=-1):
        print("features=",features)
        bin_ghost_pad=source_bin.get_static_pad("src")
        if not bin_ghost_pad.set_target(decoder_src_pad):
            sys.stderr.write("Failed to link decoder src pad to source bin ghost pad\n")


logging.basicConfig(level=logging.DEBUG, format="[%(name)s] [%(levelname)8s] - %(message)s")
logger = logging.getLogger(__name__)

Gst.init(None)

pipeline=Gst.Pipeline.new('test-pipeline')

source=Gst.ElementFactory.make('filesrc','source')
source.set_property('location', file)

demux=Gst.ElementFactory.make("qtdemux", "demux")
if not demux:
    sys.stderr.write(" Unable to create demux \n")
demux.connect("pad-added",cb_newpad)

decoder=Gst.ElementFactory.make('avdec_h264','decoder')

source.link(demux)

pipeline.add(source)
pipeline.add(demux)
pipeline.add(decoder)

srcpad = demux.get_request_pad("src")
if not srcpad:
    sys.stderr.write("Unable to get source pad of decoder \n")

sinkpad = decoder.get_static_pad("sink_0")
if not sinkpad:
    sys.stderr.write("Unable to get the sink pad of demux \n")
srcpad.link(sinkpad)

videoconvert=Gst.ElementFactory.make('videoconvert','convert')
x264enc=Gst.ElementFactory.make('x264enc','encoder')

sink=Gst.ElementFactory.make('rtspclientsink','sink')
if not sink:
    sys.stderr.write(" Unable to create udpsink")
sink.set_property("location", uri_name)

if not sink or not decoder or not videoconvert or not x264enc or not pipeline:
    logger.error('Elementlerde sıkıntı var...')
    sys.exit(1)

pipeline.add(videoconvert)
pipeline.add(x264enc)
pipeline.add(sink)

if source.link(demux):
    logger.info('src-demux Bağlandı')

if decoder.link(videoconvert):
    logger.info('decoder-videoconvert Bağlandı')
if videoconvert.link(x264enc):
    logger.info('videoconvert-x264enc Bağlandı')
if x264enc.link(sink):
    logger.info('x264enc-sink Bağlandı')

ret=pipeline.set_state(Gst.State.PLAYING)

if ret==Gst.StateChangeReturn.FAILURE:
    logger.error("pipeline'da sıkıntı var")
    sys.exit(1)

bus = pipeline.get_bus()
msg = bus.timed_pop_filtered(
    Gst.CLOCK_TIME_NONE, 
    Gst.MessageType.ERROR | Gst.MessageType.EOS)

if msg:
    if msg.type == Gst.MessageType.ERROR:
        err, debug_info = msg.parse_error()
        logger.error(f"Error received from element {msg.src.get_name()}: {err.message}")
        logger.error(f"Debugging information: {debug_info if debug_info else 'none'}")

    elif msg.type == Gst.MessageType.EOS:
        logger.info("End-Of-Stream reached.")

    else:
        # This should not happen as we only asked for ERRORs and EOS
        logger.error("Unexpected message received.")

pipeline.set_state(Gst.State.NULL)
# Out:
# Unable to get source pad of decoder
# Unable to get the sink pad of demux
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [2], line 60
#      58 if not sinkpad:
#      59     sys.stderr.write("Unable to get the sink pad of demux \n")
# ---> 60 srcpad.link(sinkpad)
#      62 videoconvert=Gst.ElementFactory.make('videoconvert','convert')
#      63 x264enc=Gst.ElementFactory.make('x264enc','encoder')
#
# AttributeError: 'NoneType' object has no attribute 'link'
